# %% [markdown]
# #Setup

# %%
import tensorflow as tf

import numpy as np
import os
import time

from keras.preprocessing.text import text_to_word_sequence
import string

# %% [markdown]
# #Downloading the Shakespeare dataset

# %%
path_to_file = tf.keras.utils.get_file('shakespeare.txt', 'https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt')

# %%
text = open(path_to_file, 'rb').read().decode(encoding='utf-8')
print ('Length of text: {} characters'.format(len(text)))
# Out:
# Length of text: 1115394 characters

# %% [markdown]
# #Data Processing

# %%
def clean_text(txt):
    txt = "".join(v for v in txt if v not in string.punctuation).lower()
    txt = txt.encode("utf8").decode("ascii",'ignore')
    return txt

# %%
corpus = clean_text(text)
data = text_to_word_sequence(corpus)
vocab = sorted(set(data))
vocab_size = len(vocab)

# %%
word2idx = {u:i for i, u in enumerate(vocab)}
idx2word = np.array(vocab)

text_as_int = np.array([word2idx[c] for c in data])

# %% [markdown]
# # Train Data Preparation

# %%
seq_length = 100
examples_per_epoch = len(text)//(seq_length+1)

dataset = tf.data.Dataset.from_tensor_slices(text_as_int)

# %%
sequences = dataset.batch(seq_length+1, drop_remainder=True)

# %%
def split_input_target(chunk):
  input_text = chunk[:-1]
  target_text = chunk[1:]
  return input_text, target_text

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 10000

train = sequences.map(split_input_target)
train = train.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
train
# Out:
# <BatchDataset shapes: ((64, 100), (64, 100)), types: (tf.int64, tf.int64)>

# %% [markdown]
# #Model Preparation

# %%
embedding_dim = 256
rnn_units = 1024

# %%
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
  model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim,
                              batch_input_shape=[batch_size, None]),
    tf.keras.layers.LSTM(rnn_units,
                        return_sequences=True,
                        stateful=True,
                        recurrent_initializer='glorot_uniform'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(vocab_size),
  ])
  return model

# %%
model = build_model(
    vocab_size = len(vocab),
    embedding_dim=embedding_dim,
    rnn_units=rnn_units,
    batch_size=BATCH_SIZE)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (64, None, 256)           3289088
# _________________________________________________________________
# lstm (LSTM)                  (64, None, 1024)          5246976
# _________________________________________________________________
# batch_normalization (BatchNo (64, None, 1024)          4096
# _________________________________________________________________
# dense (Dense)                (64, None, 12848)         13169200
# =================================================================
# Total params: 21,709,360
# Trainable params: 21,707,312
# Non-trainable params: 2,048
# _________________________________________________________________

# %% [markdown]
# #Compiling and Training the Model

# %%
def loss(labels, logits):
  return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

# %%
model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True)

# %%
EPOCHS=63

# %%
history = model.fit(train, epochs=EPOCHS, callbacks=[checkpoint_callback])
# Out:
# Epoch 1/63
# 31/31 [==============================] - 14s 455ms/step - loss: 9.0413 - accuracy: 0.0359
# Epoch 2/63
# 31/31 [==============================] - 14s 453ms/step - loss: 6.9596 - accuracy: 0.0759
# Epoch 3/63
# 31/31 [==============================] - 14s 453ms/step - loss: 5.8383 - accuracy: 0.1052
# Epoch 4/63
# 31/31 [==============================] - 14s 456ms/step - loss: 5.3185 - accuracy: 0.1219
# Epoch 5/63
# 31/31 [==============================] - 14s 456ms/step - loss: 4.8609 - accuracy: 0.1452
# Epoch 6/63
# 31/31 [==============================] - 14s 456ms/step - loss: 4.3828 - accuracy: 0.1894
# Epoch 7/63
# 31/31 [==============================] - 14s 456ms/step - loss: 3.9525 - accuracy: 0.2388
# Epoch 8/63
# 31/31 [==============================] - 14s 455ms/step - loss: 3.5717 - accuracy: 0.2892
# Epoch 9/63
# 31/31 [==============================] - 14s 459ms/step - loss: 3.2228 - accuracy: 0.3407
# Epoch 10/63
# 31/31 [==============================] - 14s 457ms/step - loss: 2.9035 - accuracy: 0.3940
# Epoch 11/63
# 31/31 [==============================] - 14s 459ms/step - loss: 2.6098 - accuracy: 0.4445
# Epoch 12/63
# 31/31 [==============================] - 14s 457ms/step - loss: 2.3530 - accuracy: 0.4928
# Epoch 13/63
# 31/31 [==============================] - 14s 455ms/step - loss: 2.1228 - accuracy: 0.5372
# Epoch 14/63
# 31/31 [==============================] - 14s 457ms/step - loss: 1.9150 - accuracy: 0.5772
# Epoch 15/63
# 31/31 [==============================] - 14s 457ms/step - loss: 1.7442 - accuracy: 0.6134
# Epoch 16/63
# 31/31 [==============================] - 14s 459ms/step - loss: 1.5770 - accuracy: 0.6496
# Epoch 17/63
# 31/31 [==============================] - 14s 459ms/step - loss: 1.4273 - accuracy: 0.6824
# Epoch 18/63
# 31/31 [==============================] - 14s 458ms/step - loss: 1.3062 - accuracy: 0.7073
# Epoch 19/63
# 31/31 [==============================] - 14s 456ms/step - loss: 1.1889 - accuracy: 0.7356
# Epoch 20/63
# 31/31 [==============================] - 14s 460ms/step - loss: 1.0833 - accuracy: 0.7595
# Epoch 21/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.9897 - accuracy: 0.7817
# Epoch 22/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.8981 - accuracy: 0.8040
# Epoch 23/63
# 31/31 [==============================] - 14s 453ms/step - loss: 0.8233 - accuracy: 0.8223
# Epoch 24/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.7486 - accuracy: 0.8406
# Epoch 25/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.6886 - accuracy: 0.8563
# Epoch 26/63
# 31/31 [==============================] - 14s 455ms/step - loss: 0.6267 - accuracy: 0.8723
# Epoch 27/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.5751 - accuracy: 0.8851
# Epoch 28/63
# 31/31 [==============================] - 14s 453ms/step - loss: 0.5280 - accuracy: 0.8971
# Epoch 29/63
# 31/31 [==============================] - 14s 455ms/step - loss: 0.4891 - accuracy: 0.9061
# Epoch 30/63
# 31/31 [==============================] - 14s 458ms/step - loss: 0.4549 - accuracy: 0.9149
# Epoch 31/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.4193 - accuracy: 0.9234
# Epoch 32/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.3951 - accuracy: 0.9290
# Epoch 33/63
# 31/31 [==============================] - 14s 455ms/step - loss: 0.3687 - accuracy: 0.9356
# Epoch 34/63
# 31/31 [==============================] - 14s 458ms/step - loss: 0.3473 - accuracy: 0.9403
# Epoch 35/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.3272 - accuracy: 0.9447
# Epoch 36/63
# 31/31 [==============================] - 14s 455ms/step - loss: 0.3110 - accuracy: 0.9480
# Epoch 37/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.2949 - accuracy: 0.9511
# Epoch 38/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.2795 - accuracy: 0.9539
# Epoch 39/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.2675 - accuracy: 0.9564
# Epoch 40/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.2547 - accuracy: 0.9592
# Epoch 41/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.2432 - accuracy: 0.9613
# Epoch 42/63
# 31/31 [==============================] - 14s 454ms/step - loss: 0.2365 - accuracy: 0.9625
# Epoch 43/63
# 31/31 [==============================] - 14s 453ms/step - loss: 0.2273 - accuracy: 0.9641
# Epoch 44/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.2194 - accuracy: 0.9651
# Epoch 45/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.2117 - accuracy: 0.9671
# Epoch 46/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.2011 - accuracy: 0.9680
# Epoch 47/63
# 31/31 [==============================] - 14s 455ms/step - loss: 0.1981 - accuracy: 0.9687
# Epoch 48/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.1939 - accuracy: 0.9694
# Epoch 49/63
# 31/31 [==============================] - 14s 454ms/step - loss: 0.1889 - accuracy: 0.9711
# Epoch 50/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.1824 - accuracy: 0.9718
# Epoch 51/63
# 31/31 [==============================] - 14s 455ms/step - loss: 0.1783 - accuracy: 0.9724
# Epoch 52/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.1718 - accuracy: 0.9734
# Epoch 53/63
# 31/31 [==============================] - 14s 458ms/step - loss: 0.1673 - accuracy: 0.9739
# Epoch 54/63
# 31/31 [==============================] - 14s 455ms/step - loss: 0.1661 - accuracy: 0.9746
# Epoch 55/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.1630 - accuracy: 0.9747
# Epoch 56/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.1578 - accuracy: 0.9755
# Epoch 57/63
# 31/31 [==============================] - 14s 457ms/step - loss: 0.1554 - accuracy: 0.9762
# Epoch 58/63
# 31/31 [==============================] - 14s 454ms/step - loss: 0.1527 - accuracy: 0.9764
# Epoch 59/63
# 31/31 [==============================] - 14s 455ms/step - loss: 0.1493 - accuracy: 0.9768
# Epoch 60/63
# 31/31 [==============================] - 14s 455ms/step - loss: 0.1454 - accuracy: 0.9778
# Epoch 61/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.1425 - accuracy: 0.9781
# Epoch 62/63
# 31/31 [==============================] - 14s 456ms/step - loss: 0.1405 - accuracy: 0.9783
# Epoch 63/63
# 31/31 [==============================] - 14s 454ms/step - loss: 0.1378 - accuracy: 0.9784

# %% [markdown]
# # Generating text

# %%
tf.train.latest_checkpoint(checkpoint_dir)
# Out:
# './training_checkpoints/ckpt_63'

# %%
model = build_model(vocab_size, embedding_dim, rnn_units, batch_size=1)

model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))

model.build(tf.TensorShape([1, None]))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (1, None, 256)            3289088
# _________________________________________________________________
# lstm_1 (LSTM)                (1, None, 1024)           5246976
# _________________________________________________________________
# batch_normalization_1 (Batch (1, None, 1024)           4096
# _________________________________________________________________
# dense_1 (Dense)              (1, None, 12848)          13169200
# =================================================================
# Total params: 21,709,360
# Trainable params: 21,707,312
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
def generate_text(model, start_string):

  # Number of words to generate
  num_generate = 10

  input_eval = [word2idx[word] for word in text_to_word_sequence(start_string)]
  input_eval = tf.expand_dims(input_eval, 0)

  text_generated = []

  temperature = 2.0

  model.reset_states()
  for i in range(num_generate):
    predictions = model(input_eval)
    predictions = tf.squeeze(predictions, 0)

    predictions = predictions / temperature
    predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

    # We pass the predicted character as the next input to the model
    # along with the previous hidden state
    input_eval = tf.expand_dims([predicted_id], 0)

    text_generated.append(idx2word[predicted_id])

  return (start_string + ' ' + ' '.join(text_generated))

# %% [markdown]
# # Result

# %%
sample_text = ["Julius", "Thou", "King is", "Death of", "The Princess"]

for pos, word in enumerate(sample_text):
  print(pos+1, generate_text(model, start_string = word))
# Out:
# 1 Julius allhating hasty benefactors once again where is my lord with
# 2 Thou man multiply they mistresslet despised so we enforce received why
# 3 King is all prithee formerly menenius thats it me skills not much
# 4 Death of paulinaa shadow hearing nor ope her lap she saintseducing even
# 5 The Princess my arms no asking my good at the time taen
